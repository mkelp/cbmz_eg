# %%
import sys
# !{sys.executable} -m pip install --user pandas
# !{sys.executable} -m pip install --user matplotlib
# !{sys.executable} -m pip install --user plotnine

# %%
#import requests
#import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import datetime as dt  # Python standard library datetime  module
import csv
from plotnine import *
from IPython.display import display, HTML
import pickle

# %%
conc_ = pd.read_pickle('initial_concs.pickle')
conc_mean = pd.read_pickle('initial_concs_mean.pickle')
conc_std = pd.read_pickle('initial_concs_std.pickle')

delta_ = pd.read_pickle('delta_concs.pickle')
delta_mean = pd.read_pickle('delta_concs_mean.pickle')
delta_std = pd.read_pickle('delta_concs_std.pickle')

met_ = pd.read_pickle('met.pickle')
met_mean = pd.read_pickle('met_mean.pickle')
met_std = pd.read_pickle('met_std.pickle')

ranges = pd.read_pickle('ranges.pickle')
print("Done")
# Out:
# Done

# %%
print((conc_.shape))
print((delta_.shape))
print((met_.shape))
print((conc_mean.shape))

eg_table = display(HTML(ranges.to_html()))
eg_table

#ggplot(conc_ , aes(x=met_.SZA, y='O3')) + geom_point()
# Out:
# (1000000, 77)
# (1000000, 77)
# (1000000, 4)
# (1, 77)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>H2SO4</th>
#       <th>HNO3</th>
#       <th>HCl</th>
#       <th>NH3</th>
#       <th>NO</th>
#       <th>NO2</th>
#       <th>NO3</th>
#       <th>N2O5</th>
#       <th>HONO</th>
#       <th>HNO4</th>
#       <th>O3</th>
#       <th>O1D</th>
#       <th>O3P</th>
#       <th>OH</th>
#       <th>HO2</th>
#       <th>H2O2</th>
#       <th>CO</th>
#       <th>SO2</th>
#       <th>CH4</th>
#       <th>C2H6</th>
#       <th>CH3O2</th>
#       <th>ETHP</th>
#       <th>HCHO</th>
#       <th>CH3OH</th>
#       <th>ANOL</th>
#       <th>CH3OOH</th>
#       <th>ETHOOH</th>
#       <th>ALD2</th>
#       <th>HCOOH</th>
#       <th>RCOOH</th>
#       <th>C2O3</th>
#       <th>PAN</th>
#       <th>ARO1</th>
#       <th>ARO2</th>
#       <th>ALK1</th>
#       <th>OLE1</th>
#       <th>API1</th>
#       <th>API2</th>
# ...
